# %% [markdown]
# <a href="https://colab.research.google.com/github/kevindo0720/TritonHacks2023-ComputerVision-Starter_Kit/blob/main/Starter_Kit_Python_Hard.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBLEM 1: Unblur the image

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# # This cell blurs the image to set up the problem

#Import required Image library
from PIL import Image, ImageFilter

# for i in range(10):
#   #Open existing image
#   OriImage = Image.open('alien.jpg')
#   blurImage = OriImage.filter(ImageFilter.BLUR)
#   #Save blurImage
#   blurImage.save('alien.jpg')

# blurImage.show();



# This cell is where users must sharpen/unblur the alien image
# Getting started
from PIL import Image, ImageEnhance
# Step 1
im = Image.open("/content/drive/MyDrive/bluralien (1).jpg")
# Step 2
enhancer = ImageEnhance.Sharpness(im)

# Step 3
factor = 75
im_s_1 = enhancer.enhance(factor)
im_s_1.show()
# Out:
# <PIL.Image.Image image mode=RGB size=767x566 at 0x7F39A7D0EE60>

# %% [markdown]
# #Task 2: Identify kidnapped humans: OpenCV, face recognition library

# %%
#set up
#take aways: emphasize the application (how is it useful in real life)
# Step 1: Identifying the locations of the faces
import cv2
# !pip install dlib
import dlib
# !sudo apt install cmake
# !pip install face_recognition
from face_recognition.api import face_distance
import face_recognition


from google.colab.patches import cv2_imshow




# Step 2: getting the count of amount of faces
image1 = face_recognition.load_image_file('/content/drive/MyDrive/group-young-friends-standing-together-over-isolated-background-pointing-displeased-frustrated-to-camera-angry-furious-235679638.jpeg')
face_locations = face_recognition.face_locations(image1)

#get count of face locations
count = len(face_locations)
# Step 3: creating the new image to be modified
image_new = cv2.imread('/content/drive/MyDrive/group-young-friends-standing-together-over-isolated-background-pointing-displeased-frustrated-to-camera-angry-furious-235679638.jpeg')

# Step 4: drawing the bounding boxes using cv2
for x in range(count):
  first_coords = (face_locations[x][1],face_locations[x][0])
  second_coords = (face_locations[x][3],face_locations[x][2])
  image_new = cv2.rectangle(image_new, first_coords, second_coords, (255, 0, 0), 3)

cv2_imshow(image_new)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3108, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2901, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 169, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 242, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 441, in run
# ...

# %% [markdown]
# #Task 3: Determine the identities of those who were kidnapped: Matplotlib

# %%
KIDNAPPED = [[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"],[12,"M"],[34,"F"],[1,"F"],[79,"F"],[46,"F"],[44,"M"],[8,"M"],[9,"M"],[98,"M"],[14,"M"],[5,"M"],[37,"M"],[79,"F"],[34,"F"],[77,"M"],[91,"M"],[23,"F"],[27,"M"],[23,"M"],[4,"M"],[16,"F"],[11,"M"],[76,"F"],[33,"F"],[39,"M"],[13,"F"],[76,"F"],[8,"F"],[12,"F"],[14,"F"],[66,"F"],[76,"F"],[76,"F"],[76,"F"],[76,"F"],[6,"F"],[65,"F"],[89,"M"],[8,"F"],[89,"F"],[11,"M"],[2,"F"],[9,"F"],[42,"M"],[9,"F"],[91,"M"],[89,"M"],[7,"F"],[76,"F"],[76,"M"],[89,"F"],[87,"F"],[6,"M"],[3,"M"],[17,"M"],[59,"F"],[43,"M"],[52,"F"],[54,"M"],[25,"F"],[77,"F"]]

#determine numbers of male, female, adults children (adults = >=18)
male = 0
female = 0
adult = 0
children = 0

for person in range(len(KIDNAPPED)):
  if (KIDNAPPED[person][0]>=18):
    adult = adult +1
  else:
    children = children +1

  if (KIDNAPPED[person][1]=="M"):
    male = male + 1
  else:
    female = female +1

#use matplotlib to visualize data
import matplotlib.pyplot as plt

data_gender = { 'male':male,
        'female':female}
keys1 = list(data_gender.keys())
values1 = list(data_gender.values())

#plot 1
fig = plt.figure(figsize = (10, 5))

# creating bar plot 1
plt.bar(keys1, values1, color ='maroon',
        width = 0.4)

plt.xlabel("gender")
plt.ylabel("number of people kidnapped")
plt.title("male vs female")
plt.show()



#plot 2
data_age = {'adult':adult, 'children':children, }
keys2 = list(data_age.keys())
values2 = list(data_age.values())


#creating barplot2
plt.bar(keys2, values2, color ='blue',
        width = 0.4)

plt.xlabel("age")
plt.ylabel("number of people kidnapped")
plt.title("adult vs children")
plt.show()

# %% [markdown]
# #Task 4: Obtain the secret information: easy OCR, OpenCV

# %%
from google.colab import drive
#STEP 1: Use EasyOCR to read the nametag and save the info into a variable
# !pip install easyocr
import os
import easyocr
import cv2

drive.mount('/content/drive')
img_ocr = cv2.imread('/content/drive/MyDrive/alien_nametag.jpg')
cv2_imshow(img_ocr) #showing the original image
#instantiate easyOCR reader
reader = easyocr.Reader(['en'])
result = reader.readtext(img_ocr, detail = 0)
result = result[0]
print(result)

#segment result into groups, print result out to determine where the 2s are
def segment_intogroups(input):
  two_locations = []
  for i in range(len(result)):
    if result[i] == "2":
      two_locations.append(i)

  #create segments of result
  big_list = []
  small_list = []
  lower_bound = 0

  for i in range(len(two_locations)):
    upper_bound = two_locations[i]
    small_list1 = result[lower_bound: upper_bound]
    small_list2 = result[upper_bound]
    big_list.append(small_list1)
    big_list.append(small_list2)
    #update lower bounds
    lower_bound = upper_bound +1

  final_small_list = result[lower_bound:]
  big_list.append(final_small_list)

  return big_list



#aline code translation
#Part 2 (HARD): Translate the name into human language
ALIEN_LANGUAGE_TRANSLATION = { '01':'A', '1000':'B',
                    '1010':'C', '100':'D', '0':'E',
                    '0010':'F', '110':'G', '0000':'H',
                    '00':'I', '0111':'J', '101':'K',
                    '0100':'L', '11':'M', '10':'N',
                    '111':'O', '0110':'P', '1101':'Q',
                    '010':'R', '000':'S', '1':'T',
                    '001':'U', '0001':'V', '011':'W',
                    '1001':'X', '1011':'Y', '1100':'Z','2': '  '}

def decrypt(message):
    cipher = ''
    for letter in message:
            cipher += ALIEN_LANGUAGE_TRANSLATION[letter]
    return cipher


print(decrypt(segment_intogroups(result)))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# <PIL.Image.Image image mode=RGB size=2354x1020 at 0x7F1838168B80>
# 100202000212010211121011
# D  E  S  T  R  O  Y

# %% [markdown]
# #Task 5: Use a machine learning model to tell humans and non humans apart: OpenCV,  Haar Cascade

# %%
import cv2

# STEP 1: Creating Functions for Processing
class Image_Processing:
    def __init__(self, img, data):
        self.img = img
        self.data = data

    def get_img_grey(self):
        return cv2.cvtColor(self.img, cv2.COLOR_BGR2GRAY)

    def get_img_rgb(self):
        return cv2.cvtColor(self.img, cv2.COLOR_BGR2RGB)

    def get_data(self, minSize):
        return self.data.detectMultiScale(self.get_img_grey(), minSize=(minSize, minSize))

# %%
# Method 1: using the Cascade Classifier to detect patterns using haar cascade
import cv2

from matplotlib import pyplot
# STEP 2: Process the image
#Create a new instance of our class: pass in the image and the .xml urls here now
img = cv2.imread("/content/drive/MyDrive/image1.jpeg")

stop_data = cv2.CascadeClassifier('face_data.xml')

# manually adjust depending on picture size
minSize = 80

# generate own haar cascade
# https://pythonprogramming.net/haar-cascade-object-detection-python-opencv-tutorial/
#Convert our image into RGB so it could be displayed properly: Fill in the blank with the function from our Image_Processing class that would convert the image to RGB
test = Image_Processing(img, stop_data)

image = test.get_img_rgb()
# Running the Function: Because our function returns a vector of rectangles, we can simply assign it to a variable as we run it. Fill in the blank with the function from our Image_Processing class that would process the image with the haar cascade data.
rects = test.get_data(minSize)
#Visualizing: To visualize our findings, we can draw the rectangles on the photo. Simply Copy and paste in the following code to start drawing rectangles in the photo:
if len(rects) != 0:
    for (x, y, width, height) in rects:
        cv2.rectangle(image, (x, y), (x + height, y + width), (0, 255, 0), 5)
#Showing the plot: copy in the following codes, you should be able to see the results.sa
pyplot.imshow(image)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-74ec10900b72> in <cell line: 20>()
#      18 image = test.get_img_rgb()
#      19
# ---> 20 rects = test.get_data(minSize)
#      21
#      22 if len(rects) != 0:
#
# <ipython-input-4-dd723b12f74f> in get_data(self, minSize)
#      14
#      15     def get_data(self, minSize):
# ---> 16         return self.data.detectMultiScale(self.get_img_grey(), minSize=(minSize, minSize))
#
# error: OpenCV(4.7.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %% [markdown]
# # Task 6: The imposters among us… Numpy, Mediapipe,  OpenCV

# %%
# Getting started
import numpy as np
import from google.colab.patches import cv2_imshow
import mediapipe as mp
from scipy import ndimage
import cv2
from matplotlib import pyplot as plt

# Background Removal
#Step 1 background removal
img = cv2.imread('image1.jpg')
background = cv2.imread('bg.jpg')

height, width, channel = img.shape

#step 2 object detection
mpSelfieSegmentation = mp.solutions.selfie_segmentation
segmentation = mpSelfieSegmentation.SelfieSegmentation(model_selection=1)

#step 3 convert image to rgb
imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#step 4 segmenting and displaying
results = segmentation.process(imgRGB)
# extract segmented mask
mask = results.segmentation_mask

# it returns true or false where the condition applies in the mask
condition = np.stack((results.segmentation_mask,) * 3, axis=-1) > 1e-5

# resize the background image to the same size of the original frame
background = cv2.resize(background, (width, height))

output_image = np.where(condition, img, background)

# show outputs
plt.imshow(output_image)
plt.show()

cv2.imwrite("output.jpg", output_image)

# Normal Map Generation

#step 5 generating normal map
imgGray = cv2.cvtColor(output_image, cv2.COLOR_RGB2BGR)

imageFloat = imgGray.astype("float64")

normals = np.array(imageFloat, dtype="float32")

print("Processing")

for i in range(1, width - 1):
    for j in range(1, height - 1):
        t = np.array([i, j - 1, imageFloat[j - 1, i, 0]], dtype="float64")
        f = np.array([i - 1, j, imageFloat[j, i - 1, 0]], dtype="float64")
        c = np.array([i, j, imageFloat[j, i, 0]], dtype="float64")
        d = np.cross(f - c, t - c)
        n = d / np.sqrt((np.sum(d ** 2)))
        normals[j, i, :] = n


print("done")

normals *= 255

cv2_imshow("normal.jpg", normals)
